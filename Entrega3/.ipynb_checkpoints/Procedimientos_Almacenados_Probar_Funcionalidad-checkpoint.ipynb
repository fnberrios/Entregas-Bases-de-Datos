# %%
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7600c8b786e3> in <module>
# ----> 1 get_ipython().run_line_magic('load_ext', 'sql')
#
# c:\users\franc\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2324                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2325             with self.builtin_trap:
# -> 2326                 result = fn(*args, **kwargs)
#    2327             return result
#    2328
#
# <decorator-gen-65> in load_ext(self, module_str)
#
# c:\users\franc\appdata\local\programs\python\python37\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
# ...

# %%
# %%sql
# postgresql://grupo30:grupo30@codd.ing.puc.cl/grupo30e2
# Out:
# 'Connected: grupo30@grupo30e2'

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION
# destinos_permitidos ()
# RETURNS TABLE (origen varchar, destino varchar) AS $$
# BEGIN
# RETURN QUERY SELECT DISTINCT t1.ciudad_origen, t1.nombreciudad FROM
#     dblink('dbname=grupo53e3 host=localhost user=grupo53 password=grupo53',
#     'SELECT ciudad_origen, nombreciudad FROM Destinos INNER JOIN Viaje ON Destinos.did=Viaje.did INNER
#     JOIN Ciudades ON Ciudades.cid=Viaje.cid') AS t1(ciudad_origen varchar, nombreciudad varchar);
# RETURN;
# END;
# $$ language plpgsql
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# Done.
# []

# %%
# %sql SELECT * FROM destinos_permitidos();
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 22 rows affected.
# [('Paris', 'Florencia'),
#  ('Florencia', 'Paris'),
#  ('Nancy', 'Chantilly'),
#  ('Westminster', 'Bruselas'),
#  ('Bruselas', 'Antwerp'),
#  ('Milan', 'Florencia'),
#  ('Roma', 'Paris'),
#  ('Milan', 'Dresde'),
#  ('Dresde', 'Milan'),
#  ('Chantilly', 'Nancy'),
#  ('Bruselas', 'Westminster'),
#  ('Dresde', 'Bruselas'),
#  ('Paris', 'Chantilly'),
#  ('Bruselas', 'Paris'),
#  ('Paris', 'Roma'),
#  ('Bruselas', 'Dresde'),
#  ('Antwerp', 'Bruselas'),
#  ('Chantilly', 'Paris'),
#  ('Roma', 'Florencia'),
#  ('Florencia', 'Milan'),
#  ('Florencia', 'Roma'),
#  ('Paris', 'Bruselas')]

# %% [markdown]
# #Escalas

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION
# una_escala ()
# RETURNS TABLE (origen varchar, ciudad1 varchar, final varchar) AS $$
# BEGIN
# RETURN QUERY SELECT A.origen AS origen, A.destino AS ciudad1,
#     B.destino AS ciudad2
#     FROM destinos_permitidos() as A,
#     destinos_permitidos() as B
#     WHERE A.destino=B.origen;
# RETURN;
# END;
# $$ language plpgsql
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# Done.
# []

# %%
# %sql SELECT * FROM una_escala();
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 60 rows affected.
# [('Bruselas', 'Antwerp', 'Bruselas'),
#  ('Paris', 'Bruselas', 'Westminster'),
#  ('Paris', 'Bruselas', 'Dresde'),
#  ('Paris', 'Bruselas', 'Paris'),
#  ('Paris', 'Bruselas', 'Antwerp'),
#  ('Westminster', 'Bruselas', 'Westminster'),
#  ('Westminster', 'Bruselas', 'Dresde'),
#  ('Westminster', 'Bruselas', 'Paris'),
#  ('Westminster', 'Bruselas', 'Antwerp'),
#  ('Dresde', 'Bruselas', 'Westminster'),
#  ('Dresde', 'Bruselas', 'Dresde'),
#  ('Dresde', 'Bruselas', 'Paris'),
#  ('Dresde', 'Bruselas', 'Antwerp'),
#  ('Antwerp', 'Bruselas', 'Westminster'),
#  ('Antwerp', 'Bruselas', 'Dresde'),
#  ('Antwerp', 'Bruselas', 'Paris'),
#  ('Antwerp', 'Bruselas', 'Antwerp'),
#  ('Paris', 'Chantilly', 'Nancy'),
#  ('Paris', 'Chantilly', 'Paris'),
#  ('Nancy', 'Chantilly', 'Nancy'),
#  ('Nancy', 'Chantilly', 'Paris'),
#  ('Bruselas', 'Dresde', 'Bruselas'),
#  ('Bruselas', 'Dresde', 'Milan'),
# ...

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION
# dos_escalas (ciudad_origen varchar)
# RETURNS TABLE (origen varchar, ciudad1 varchar, ciudad2 varchar, final varchar) AS $$
# BEGIN
# RETURN QUERY SELECT A.origen AS origen, A.ciudad1 AS ciudad1, A.final AS ciudad2,
#     B.destino AS destino
#     FROM una_escala() as A,
#     destinos_permitidos() as B
#     WHERE A.final=B.origen AND A.origen=ciudad_origen;
# RETURN;
# END;
# $$ language plpgsql
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# Done.
# []

# %%
# %sql SELECT * FROM dos_escalas('Florencia');
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 23 rows affected.
# [('Florencia', 'Roma', 'Paris', 'Florencia'),
#  ('Florencia', 'Roma', 'Florencia', 'Paris'),
#  ('Florencia', 'Paris', 'Florencia', 'Paris'),
#  ('Florencia', 'Milan', 'Florencia', 'Paris'),
#  ('Florencia', 'Paris', 'Bruselas', 'Antwerp'),
#  ('Florencia', 'Paris', 'Roma', 'Paris'),
#  ('Florencia', 'Milan', 'Dresde', 'Milan'),
#  ('Florencia', 'Paris', 'Chantilly', 'Nancy'),
#  ('Florencia', 'Paris', 'Bruselas', 'Westminster'),
#  ('Florencia', 'Milan', 'Dresde', 'Bruselas'),
#  ('Florencia', 'Roma', 'Paris', 'Chantilly'),
#  ('Florencia', 'Paris', 'Bruselas', 'Paris'),
#  ('Florencia', 'Roma', 'Paris', 'Roma'),
#  ('Florencia', 'Paris', 'Bruselas', 'Dresde'),
#  ('Florencia', 'Paris', 'Chantilly', 'Paris'),
#  ('Florencia', 'Paris', 'Roma', 'Florencia'),
#  ('Florencia', 'Roma', 'Florencia', 'Milan'),
#  ('Florencia', 'Paris', 'Florencia', 'Milan'),
#  ('Florencia', 'Milan', 'Florencia', 'Milan'),
# ...

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION
# itinerario()
# RETURNS TABLE (origen varchar, ciudad1 varchar, ciudad2 varchar, final varchar) AS $$
# BEGIN
# RETURN QUERY SELECT A.origen AS origen, A.ciudad1 AS ciudad1, A.final AS ciudad2,
#     B.destino AS destino
#     FROM una_escala() as A,
#     destinos_permitidos() as B
#     WHERE A.final=B.origen;
# RETURN;
# END;
# $$ language plpgsql
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# Done.
# []

# %% [markdown]
# # Ubicacion de artistas

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION
# ubicacion_artistas (lista_artistas varchar[])
# RETURNS TABLE (artistas varchar, ciudad varchar) AS $$
# BEGIN
# RETURN QUERY SELECT DISTINCT Artistas.anombre, Ciudades.cnombre FROM Artistas
#     INNER JOIN Creo ON Artistas.aid=Creo.aid INNER JOIN Obras ON Obras.oid=Creo.oid
#     INNER JOIN Lugares ON Obras.lid=Lugares.lid INNER JOIN Ciudades ON Ciudades.cid=Lugares.cid
#     INNER JOIN unnest(lista_artistas) lista ON Artistas.anombre=lista;
# RETURN;
# END;
# $$ language plpgsql
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# Done.
# []

# %%
# %sql SELECT * FROM ubicacion_artistas(ARRAY ['Jerome Duquesnoy', 'Leonardo da Vinci', 'Donatello']);
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 5 rows affected.
# [('Jerome Duquesnoy', 'Bruselas'),
#  ('Leonardo da Vinci', 'Milan'),
#  ('Donatello', 'Florencia'),
#  ('Leonardo da Vinci', 'Florencia'),
#  ('Leonardo da Vinci', 'Paris')]

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION
# ubicaciones_dos_artistas2 (artistas varchar, cantidad_join integer)
# RETURNS TABLE (artista1 varchar, ciudad1 varchar, artista2 varchar, ciudad2 varchar,
#                artista3 varchar, ciudad3 varchar,artista4 varchar, ciudad4 varchar) AS $$
# DECLARE
# lista_artistas varchar[];
# BEGIN
# lista_artistas := ARRAY(SELECT * FROM STRING_SPLIT(artistas,','));
#
# IF cantidad_join < 2 THEN
#     RETURN QUERY SELECT A.artistas AS name1, B.artistas AS name2,
#     A.ciudad AS city1, B.ciudad AS city2
#     FROM ubicacion_artistas(lista_artistas) as A,
#     ubicacion_artistas(lista_artistas) as B
#     WHERE A.artistas!=B.artistas;
# END IF;
#
# RETURN QUERY SELECT *
#     FROM ubicacion_artistas(lista_artistas) as A,
#     ubicaciones_dos_artistas(lista_artistas, cantidad_join-1) as B;
# RETURN;
# END;
# $$ language plpgsql
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# Done.
# []

# %%
# %sql SELECT * FROM ubicaciones_dos_artistas(ARRAY ['Jerome Duquesnoy', 'Leonardo da Vinci', 'Donatello'], 2);
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# (psycopg2.ProgrammingError) structure of query does not match function result type
# DETAIL:  Number of returned columns (6) does not match expected column count (4).
# CONTEXT:  PL/pgSQL function ubicaciones_dos_artistas(character varying[],integer) line 12 at RETURN QUERY
#
# [SQL: SELECT * FROM ubicaciones_dos_artistas(ARRAY ['Jerome Duquesnoy', 'Leonardo da Vinci', 'Donatello'], 2);]
# (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# # Crear tabla

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION
# itinerario_cuatro_ciudades (lista_artistas varchar[], ciudad_origen varchar)
# RETURNS TABLE (ciudades VARCHAR[], artistas VARCHAR[]) AS $$
# DECLARE
#     combi_ciudades varchar[];
#     posibles_artistas varchar[];
#     resultado varchar[];
#     tupla RECORD;
# BEGIN
# DROP TABLE IF EXISTS itinerario_ciudades;
# CREATE TABLE itinerario_ciudades (ciudades VARCHAR[], artistas VARCHAR[]);
#
# FOR tupla IN SELECT * FROM dos_escalas(ciudad_origen) LOOP
# combi_ciudades := ARRAY [tupla.origen, tupla.ciudad1, tupla.ciudad2, tupla.final];
# posibles_artistas := ARRAY(SELECT DISTINCT Artistas.anombre FROM Artistas
#       INNER JOIN Creo ON Artistas.aid=Creo.aid INNER JOIN Obras ON Obras.oid=Creo.oid
#       INNER JOIN Lugares ON Obras.lid=Lugares.lid INNER JOIN Ciudades ON Ciudades.cid=Lugares.cid
#       INNER JOIN unnest(lista_artistas) lista ON
#       Artistas.anombre=lista INNER JOIN unnest(combi_ciudades) lista2 ON Ciudades.cnombre=lista2);
# INSERT INTO itinerario_ciudades VALUES (combi_ciudades, posibles_artistas);
# END LOOP;
# RETURN QUERY SELECT * FROM itinerario_ciudades WHERE
# ARRAY(SELECT unnest(itinerario_ciudades.artistas) ORDER BY 1)=
# ARRAY(SELECT unnest(lista_artistas) ORDER BY 1);
# RETURN;
# END;
# $$ language plpgsql
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# Done.
# []

# %%
# %sql SELECT DISTINCT ciudades FROM itinerario_cuatro_ciudades(ARRAY ['Jerome Duquesnoy', 'Leonardo da Vinci', 'Donatello'], 'Florencia');
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 6 rows affected.
# [(['Florencia', 'Paris', 'Bruselas', 'Westminster'],),
#  (['Florencia', 'Paris', 'Bruselas', 'Dresde'],),
#  (['Florencia', 'Roma', 'Paris', 'Bruselas'],),
#  (['Florencia', 'Milan', 'Dresde', 'Bruselas'],),
#  (['Florencia', 'Paris', 'Bruselas', 'Paris'],),
#  (['Florencia', 'Paris', 'Bruselas', 'Antwerp'],)]

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION
# itinerario_dos_ciudades (lista_artistas varchar[], ciudad_origen varchar)
# RETURNS TABLE (ciudades VARCHAR[], artistas VARCHAR[]) AS $$
# DECLARE
#     combi_ciudades varchar[];
#     posibles_artistas varchar[];
#     resultado varchar[];
#     tupla RECORD;
# BEGIN
# DROP TABLE IF EXISTS itinerario_ciudades;
# CREATE TABLE itinerario_ciudades (ciudades VARCHAR[], artistas VARCHAR[]);
#
# FOR tupla IN SELECT origen, ciudad1 FROM dos_escalas(ciudad_origen) LOOP
# combi_ciudades := ARRAY [tupla.origen, tupla.ciudad1];
# posibles_artistas := ARRAY(SELECT DISTINCT Artistas.anombre FROM Artistas
#       INNER JOIN Creo ON Artistas.aid=Creo.aid INNER JOIN Obras ON Obras.oid=Creo.oid
#       INNER JOIN Lugares ON Obras.lid=Lugares.lid INNER JOIN Ciudades ON Ciudades.cid=Lugares.cid
#       INNER JOIN unnest(lista_artistas) lista ON
#       Artistas.anombre=lista INNER JOIN unnest(combi_ciudades) lista2 ON Ciudades.cnombre=lista2);
# INSERT INTO itinerario_ciudades VALUES (combi_ciudades, posibles_artistas);
# END LOOP;
# RETURN QUERY SELECT * FROM itinerario_ciudades WHERE
# ARRAY(SELECT unnest(itinerario_ciudades.artistas) ORDER BY 1)=
# ARRAY(SELECT unnest(lista_artistas) ORDER BY 1);
# RETURN;
# END;
# $$ language plpgsql
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# Done.
# []

# %%
# %sql SELECT DISTINCT ciudades FROM itinerario_dos_ciudades(ARRAY ['Leonardo da Vinci', 'Donatello'], 'Florencia');
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 3 rows affected.
# [(['Florencia', 'Roma'],),
#  (['Florencia', 'Milan'],),
#  (['Florencia', 'Paris'],)]

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION
# itinerario_tres_ciudades (lista_artistas varchar[], ciudad_origen varchar)
# RETURNS TABLE (ciudades VARCHAR[], artistas VARCHAR[]) AS $$
# DECLARE
#     combi_ciudades varchar[];
#     posibles_artistas varchar[];
#     resultado varchar[];
#     tupla RECORD;
# BEGIN
# DROP TABLE IF EXISTS itinerario_ciudades;
# CREATE TABLE itinerario_ciudades (ciudades VARCHAR[], artistas VARCHAR[]);
#
# FOR tupla IN SELECT origen, ciudad1, ciudad2 FROM dos_escalas(ciudad_origen) LOOP
# combi_ciudades := ARRAY [tupla.origen, tupla.ciudad1, tupla.ciudad2];
# posibles_artistas := ARRAY(SELECT DISTINCT Artistas.anombre FROM Artistas
#       INNER JOIN Creo ON Artistas.aid=Creo.aid INNER JOIN Obras ON Obras.oid=Creo.oid
#       INNER JOIN Lugares ON Obras.lid=Lugares.lid INNER JOIN Ciudades ON Ciudades.cid=Lugares.cid
#       INNER JOIN unnest(lista_artistas) lista ON
#       Artistas.anombre=lista INNER JOIN unnest(combi_ciudades) lista2 ON Ciudades.cnombre=lista2);
# INSERT INTO itinerario_ciudades VALUES (combi_ciudades, posibles_artistas);
# END LOOP;
# RETURN QUERY SELECT * FROM itinerario_ciudades WHERE
# ARRAY(SELECT unnest(itinerario_ciudades.artistas) ORDER BY 1)=
# ARRAY(SELECT unnest(lista_artistas) ORDER BY 1);
#
# RETURN;
# END;
# $$ language plpgsql
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# Done.
# []

# %%
# %sql SELECT DISTINCT ciudades FROM itinerario_tres_ciudades(string_to_array('Jerome Duquesnoy,Leonardo da Vinci,Donatello',','), 'Florencia');
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 1 rows affected.
# [(['Florencia', 'Paris', 'Bruselas'],)]

# %%
# %sql SELECT DISTINCT ciudades FROM itinerario_tres_ciudades(string_to_array('Donatello,Jerome Duquesnoy,Leonardo da Vinci',','), 'Florencia');
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 1 rows affected.
# [(['Florencia', 'Paris', 'Bruselas'],)]

# %% [markdown]
# # Finalizando itinerarios

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION
# info_itinerario_tres_ciudades (lista_artistas varchar[], ciudad_origen varchar)
# RETURNS VOID AS $$
# DECLARE
#     tupla varchar[];
#     tupla1 RECORD;
#     tupla2 RECORD;
#     id_variable integer;
# BEGIN
# DROP TABLE IF EXISTS medios_precios;
# DROP TABLE IF EXISTS info_itinerarios;
# CREATE TABLE medios_precios (id_itinerario integer, ciudad1 VARCHAR,
#                              ciudad2 VARCHAR, medio VARCHAR,
#                              precio integer, duracion integer, hora_salida time);
# CREATE TABLE info_itinerarios (id_itinerario integer, precio_total integer);
# id_variable := 1;
#
# FOR tupla IN SELECT DISTINCT ciudades FROM itinerario_tres_ciudades(lista_artistas, ciudad_origen) LOOP
#
#   FOR tupla1 IN SELECT t1.ciudad_origen, t1.nombreciudad, t1.medio, t1.precio, t1.duracion, t1.hora_salida FROM
#     dblink('dbname=grupo53e3 host=localhost user=grupo53 password=grupo53',
#     'SELECT ciudad_origen, nombreciudad, medio, precio, duracion, hora_salida FROM Destinos INNER JOIN Viaje ON Destinos.did=Viaje.did INNER
#     JOIN Ciudades ON Ciudades.cid=Viaje.cid') AS
#     t1(ciudad_origen varchar, nombreciudad varchar, medio varchar, precio integer, duracion integer, hora_salida time)
#     WHERE t1.ciudad_origen=tupla[1] AND t1.nombreciudad=tupla[2] LOOP
#
#
#     FOR tupla2 IN SELECT t2.ciudad_origen, t2.nombreciudad, t2.medio, t2.precio, t2.duracion, t2.hora_salida FROM
#       dblink('dbname=grupo53e3 host=localhost user=grupo53 password=grupo53',
#       'SELECT ciudad_origen, nombreciudad, medio, precio, duracion, hora_salida FROM Destinos INNER JOIN Viaje ON Destinos.did=Viaje.did INNER
#       JOIN Ciudades ON Ciudades.cid=Viaje.cid')
#       AS t2(ciudad_origen varchar, nombreciudad varchar, medio varchar, precio integer, duracion integer, hora_salida time)
#       WHERE t2.ciudad_origen=tupla[2] AND t2.nombreciudad=tupla[3] LOOP
#
#       INSERT INTO medios_precios VALUES (id_variable, tupla1.ciudad_origen, tupla1.nombreciudad,
#                                   tupla1.medio, tupla1.precio, tupla1.duracion, tupla1.hora_salida);
#
#       INSERT INTO medios_precios VALUES (id_variable, tupla2.ciudad_origen, tupla2.nombreciudad,
#                                        tupla2.medio, tupla2.precio, tupla2.duracion, tupla2.hora_salida);
#       id_variable := id_variable + 1;
#
#
#     END LOOP;
#     id_variable := id_variable + 1;
#   END LOOP;
# END LOOP;
#
# END;
# $$ language plpgsql
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# Done.
# []

# %%
# %sql SELECT info_itinerario_tres_ciudades(string_to_array('Donatello,Jerome Duquesnoy,Leonardo da Vinci',','), 'Florencia');
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 1 rows affected.
# [('',)]

# %%
# %sql SELECT info_itinerario_tres_ciudades(string_to_array('Jerome Duquesnoy,Leonardo da Vinci,Donatello',','), 'Florencia');
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 1 rows affected.
# [('',)]

# %%
# %sql SELECT id_itinerario, SUM(precio) AS total FROM medios_precios GROUP BY id_itinerario ORDER BY total;
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM medios_precios;
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 36 rows affected.
# [(1, 'Florencia', 'Paris', 'Tren', 40, 3, datetime.time(14, 45)),
#  (1, 'Paris', 'Bruselas', 'Avion', 100, 2, datetime.time(15, 45)),
#  (2, 'Florencia', 'Paris', 'Tren', 40, 3, datetime.time(14, 45)),
#  (2, 'Paris', 'Bruselas', 'Tren', 45, 5, datetime.time(13, 42)),
#  (3, 'Florencia', 'Paris', 'Tren', 40, 3, datetime.time(14, 45)),
#  (3, 'Paris', 'Bruselas', 'Avion', 100, 2, datetime.time(23, 43)),
#  (4, 'Florencia', 'Paris', 'Tren', 40, 3, datetime.time(14, 45)),
#  (4, 'Paris', 'Bruselas', 'Tren', 45, 5, datetime.time(8, 54)),
#  (5, 'Florencia', 'Paris', 'Tren', 40, 3, datetime.time(14, 45)),
#  (5, 'Paris', 'Bruselas', 'Tren', 45, 5, datetime.time(11, 34)),
#  (6, 'Florencia', 'Paris', 'Tren', 40, 3, datetime.time(14, 45)),
#  (6, 'Paris', 'Bruselas', 'Avion', 100, 2, datetime.time(9, 30)),
#  (8, 'Florencia', 'Paris', 'Tren', 49, 3, datetime.time(8, 23)),
# ...

# %%
# %sql SELECT info_itinerario_tres_ciudades(string_to_array('Donatello,Jerome Duquesnoy,Leonardo da Vinci',','), 'Florencia');
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 1 rows affected.
# [('',)]

# %%
# %sql SELECT * FROM medios_precios;
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 0 rows affected.
# []

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION
# info_itinerario_cuatro_ciudades (lista_artistas varchar[], ciudad_origen varchar)
# RETURNS VOID AS $$
# DECLARE
#     tupla varchar[];
#     tupla1 RECORD;
#     tupla2 RECORD;
#     tupla3 RECORD;
#     id_variable integer;
# BEGIN
# DROP TABLE IF EXISTS medios_precios;
# DROP TABLE IF EXISTS info_itinerarios;
# CREATE TABLE medios_precios (id_itinerario integer, ciudad1 VARCHAR,
#                              ciudad2 VARCHAR, medio VARCHAR,
#                              precio integer, duracion integer, hora_salida time);
# CREATE TABLE info_itinerarios (id_itinerario integer, precio_total integer);
# id_variable := 1;
#
# FOR tupla IN SELECT DISTINCT ciudades FROM itinerario_cuatro_ciudades(lista_artistas, ciudad_origen) LOOP
#
#   FOR tupla1 IN SELECT t1.ciudad_origen, t1.nombreciudad, t1.medio, t1.precio, t1.duracion, t1.hora_salida FROM
#     dblink('dbname=grupo53e3 host=localhost user=grupo53 password=grupo53',
#     'SELECT ciudad_origen, nombreciudad, medio, precio, duracion, hora_salida FROM Destinos INNER JOIN Viaje ON Destinos.did=Viaje.did INNER
#     JOIN Ciudades ON Ciudades.cid=Viaje.cid') AS
#     t1(ciudad_origen varchar, nombreciudad varchar, medio varchar, precio integer, duracion integer, hora_salida time)
#     WHERE t1.ciudad_origen=tupla[1] AND t1.nombreciudad=tupla[2] LOOP
#
#
#     FOR tupla2 IN SELECT t2.ciudad_origen, t2.nombreciudad, t2.medio, t2.precio, t2.duracion, t2.hora_salida FROM
#       dblink('dbname=grupo53e3 host=localhost user=grupo53 password=grupo53',
#       'SELECT ciudad_origen, nombreciudad, medio, precio, duracion, hora_salida FROM Destinos INNER JOIN Viaje ON Destinos.did=Viaje.did INNER
#       JOIN Ciudades ON Ciudades.cid=Viaje.cid')
#       AS t2(ciudad_origen varchar, nombreciudad varchar, medio varchar, precio integer, duracion integer, hora_salida time)
#       WHERE t2.ciudad_origen=tupla[2] AND t2.nombreciudad=tupla[3] LOOP
#
#       FOR tupla3 IN SELECT t3.ciudad_origen, t3.nombreciudad, t3.medio, t3.precio, t3.duracion, t3.hora_salida FROM
#         dblink('dbname=grupo53e3 host=localhost user=grupo53 password=grupo53',
#         'SELECT ciudad_origen, nombreciudad, medio, precio, duracion, hora_salida FROM Destinos INNER JOIN Viaje ON Destinos.did=Viaje.did INNER
#         JOIN Ciudades ON Ciudades.cid=Viaje.cid')
#         AS t3(ciudad_origen varchar, nombreciudad varchar, medio varchar, precio integer, duracion integer, hora_salida time)
#         WHERE t3.ciudad_origen=tupla[3] AND t3.nombreciudad=tupla[4] LOOP
#
#
#
#           INSERT INTO medios_precios VALUES (id_variable, tupla1.ciudad_origen, tupla1.nombreciudad,
#                                   tupla1.medio, tupla1.precio, tupla1.duracion, tupla1.hora_salida);
#
#           INSERT INTO medios_precios VALUES (id_variable, tupla2.ciudad_origen, tupla2.nombreciudad,
#                                        tupla2.medio, tupla2.precio, tupla2.duracion, tupla2.hora_salida);
#
#           INSERT INTO medios_precios VALUES (id_variable, tupla3.ciudad_origen, tupla3.nombreciudad,
#                                        tupla3.medio, tupla3.precio, tupla3.duracion, tupla3.hora_salida);
#
#           id_variable := id_variable + 1;
#         END LOOP;
#       id_variable := id_variable + 1;
#     END LOOP;
#     id_variable := id_variable + 1;
#   END LOOP;
# END LOOP;
#
# END;
# $$ language plpgsql
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# Done.
# []

# %%
# %sql SELECT info_itinerario_cuatro_ciudades(string_to_array('Donatello,Jerome Duquesnoy,Leonardo da Vinci',','), 'Florencia');
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 1 rows affected.
# [('',)]

# %%
# %sql SELECT * FROM medios_precios;
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 3648 rows affected.
# [(1, 'Florencia', 'Milan', 'Tren', 32, 3, datetime.time(21, 55)),
#  (1, 'Milan', 'Florencia', 'Tren', 32, 3, datetime.time(7, 12)),
#  (1, 'Florencia', 'Paris', 'Tren', 40, 3, datetime.time(14, 45)),
#  (2, 'Florencia', 'Milan', 'Tren', 32, 3, datetime.time(21, 55)),
#  (2, 'Milan', 'Florencia', 'Tren', 32, 3, datetime.time(7, 12)),
#  (2, 'Florencia', 'Paris', 'Tren', 49, 3, datetime.time(8, 23)),
#  (3, 'Florencia', 'Milan', 'Tren', 32, 3, datetime.time(21, 55)),
#  (3, 'Milan', 'Florencia', 'Tren', 32, 3, datetime.time(7, 12)),
#  (3, 'Florencia', 'Paris', 'Tren', 40, 3, datetime.time(16, 12)),
#  (5, 'Florencia', 'Milan', 'Tren', 32, 3, datetime.time(21, 55)),
#  (5, 'Milan', 'Florencia', 'Bus', 20, 6, datetime.time(18, 56)),
#  (5, 'Florencia', 'Paris', 'Tren', 40, 3, datetime.time(14, 45)),
#  (6, 'Florencia', 'Milan', 'Tren', 32, 3, datetime.time(21, 55)),
# ...

# %%
# %sql SELECT id_itinerario, SUM(precio) AS total FROM medios_precios GROUP BY id_itinerario ORDER BY total;
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 1216 rows affected.
# [(1149, 60),
#  (1145, 60),
#  (1128, 60),
#  (1123, 60),
#  (1144, 60),
#  (1150, 60),
#  (1124, 60),
#  (1129, 60),
#  (766, 65),
#  (760, 65),
#  (782, 65),
#  (765, 65),
#  (787, 65),
#  (786, 65),
#  (781, 65),
#  (761, 65),
#  (1439, 70),
#  (1438, 70),
#  (1444, 70),
#  (1459, 70),
#  (1460, 70),
#  (1443, 70),
#  (1464, 70),
#  (1465, 70),
#  (1140, 72),
#  (1155, 72),
#  (1107, 72),
#  (1133, 72),
#  (1125, 72),
#  (1130, 72),
#  (1127, 72),
#  (1165, 72),
#  (1119, 72),
#  (1108, 72),
#  (1103, 72),
#  (1122, 72),
#  (1134, 72),
#  (1148, 72),
#  (1166, 72),
#  (1143, 72),
#  (1151, 72),
#  (1171, 72),
#  (1139, 72),
#  (1102, 72),
#  (1170, 72),
#  (1146, 72),
#  (1118, 72),
#  (1154, 72),
#  (764, 75),
#  (677, 75),
#  (681, 75),
#  (697, 75),
#  (759, 75),
#  (702, 75),
#  (682, 75),
#  (767, 75),
#  (703, 75),
#  (783, 75),
#  (698, 75),
#  (785, 75),
#  (788, 75),
#  (780, 75),
#  (762, 75),
# ...

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION
# info_itinerario_dos_ciudades (lista_artistas varchar[], ciudad_origen varchar)
# RETURNS VOID AS $$
# DECLARE
#     tupla varchar[];
#     tupla1 RECORD;
#     id_variable integer;
# BEGIN
# DROP TABLE IF EXISTS medios_precios;
# DROP TABLE IF EXISTS info_itinerarios;
# CREATE TABLE medios_precios (id_itinerario integer, ciudad1 VARCHAR,
#                              ciudad2 VARCHAR, medio VARCHAR,
#                              precio integer, duracion integer, hora_salida time);
# CREATE TABLE info_itinerarios (id_itinerario integer, precio_total integer);
# id_variable := 1;
#
# FOR tupla IN SELECT DISTINCT ciudades FROM itinerario_dos_ciudades(lista_artistas, ciudad_origen) LOOP
#
#   FOR tupla1 IN SELECT t1.ciudad_origen, t1.nombreciudad, t1.medio, t1.precio, t1.duracion, t1.hora_salida FROM
#     dblink('dbname=grupo53e3 host=localhost user=grupo53 password=grupo53',
#     'SELECT ciudad_origen, nombreciudad, medio, precio, duracion, hora_salida FROM Destinos INNER JOIN Viaje ON Destinos.did=Viaje.did INNER
#     JOIN Ciudades ON Ciudades.cid=Viaje.cid') AS
#     t1(ciudad_origen varchar, nombreciudad varchar, medio varchar, precio integer, duracion integer, hora_salida time)
#     WHERE t1.ciudad_origen=tupla[1] AND t1.nombreciudad=tupla[2] LOOP
#
#     INSERT INTO medios_precios VALUES (id_variable, tupla1.ciudad_origen, tupla1.nombreciudad,
#                                   tupla1.medio, tupla1.precio, tupla1.duracion, tupla1.hora_salida);
#
#     id_variable := id_variable + 1;
#   END LOOP;
# END LOOP;
#
# END;
# $$ language plpgsql
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# Done.
# []

# %%
# %sql SELECT info_itinerario_dos_ciudades(string_to_array('Donatello,Leonardo da Vinci',','), 'Florencia');
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 1 rows affected.
# [('',)]

# %%
# %sql SELECT * FROM medios_precios;
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 11 rows affected.
# [(1, 'Florencia', 'Roma', 'Tren', 35, 5, datetime.time(11, 34)),
#  (2, 'Florencia', 'Roma', 'Bus', 25, 6, datetime.time(11, 34)),
#  (3, 'Florencia', 'Roma', 'Bus', 25, 6, datetime.time(22, 43)),
#  (4, 'Florencia', 'Roma', 'Tren', 35, 5, datetime.time(22, 43)),
#  (5, 'Florencia', 'Milan', 'Tren', 32, 3, datetime.time(21, 55)),
#  (6, 'Florencia', 'Milan', 'Bus', 20, 6, datetime.time(21, 55)),
#  (7, 'Florencia', 'Milan', 'Bus', 20, 6, datetime.time(10, 43)),
#  (8, 'Florencia', 'Milan', 'Tren', 32, 3, datetime.time(10, 43)),
#  (9, 'Florencia', 'Paris', 'Tren', 40, 3, datetime.time(14, 45)),
#  (10, 'Florencia', 'Paris', 'Tren', 49, 3, datetime.time(8, 23)),
#  (11, 'Florencia', 'Paris', 'Tren', 40, 3, datetime.time(16, 12))]

# %%
# %sql SELECT id_itinerario, SUM(precio) AS total FROM medios_precios GROUP BY id_itinerario ORDER BY total;
# Out:
#  * postgresql://grupo30:***@codd.ing.puc.cl/grupo30e2
# 11 rows affected.
# [(7, 20),
#  (6, 20),
#  (2, 25),
#  (3, 25),
#  (8, 32),
#  (5, 32),
#  (4, 35),
#  (1, 35),
#  (11, 40),
#  (9, 40),
#  (10, 49)]
